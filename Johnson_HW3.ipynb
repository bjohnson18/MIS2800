# %% [markdown]
# <a href="https://colab.research.google.com/github/bjohnson18/MIS2800/blob/main/Johnson_HW3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Type this code exactly as shown to intall the first library needed for
# !pip install --upgrade pandas ipython-sql prettytable==3.10.1

# %%
# Install the SQL extension. Remember to type exactly as shown here.
# !pip install ipython-sql
print("ipython sql installed")
# Out:
# ...
# ipython sql installed

# %%
# Load the SQL magic extension
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
#this code imports sqlite3 and prints a statement stating it has been im
import sqlite3
print("sqlite3 imported")
# Out:
# sqlite3 imported

# %%
# This creates a brand-new, empty database file named 'AdCampaigns2026.d
conn = sqlite3.connect('AdCampaigns2026.db')
print("database created")
# Out:
# database created

# %%
# This line is required so Colab stops acting like Python and acts more
# %sql sqlite:///AdCampaigns2026.db

# %%
#Block 1
# %%sql
CREATE TABLE Marketing_Brands (
  brand_id INTEGER PRIMARY KEY,
  brand_name TEXT,
  brand_type TEXT,
  brand_budget INTEGER
) STRICT;
# Out:
#  * sqlite:///AdCampaigns2026.db
# (sqlite3.OperationalError) table Marketing_Brands already exists
# [SQL: CREATE TABLE Marketing_Brands (
#   brand_id INTEGER PRIMARY KEY,
#   brand_name TEXT,
#   brand_type TEXT,
#   brand_budget INTEGER
# ) STRICT;]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
#Block 2
# %%sql
INSERT INTO Marketing_Brands (brand_id, brand_name, brand_type, brand_budget)
VALUES
(1, 'Doritos', 'Snacks', 7000000),
(2, 'AWS', 'Technology', 15000000),
(3, 'Pepsi', 'Beverages', 2000000),
(4, 'He_Gets_Us', 'Religious', 1000000),
(5, 'Dr_Pepper', 'Beverages', 5000000),
(6, 'IBM', 'Technology', 100000),
(7, 'Google', 'Technology', 8000000);
# Out:
#  * sqlite:///AdCampaigns2026.db
# (sqlite3.IntegrityError) UNIQUE constraint failed: Marketing_Brands.brand_id
# [SQL: INSERT INTO Marketing_Brands (brand_id, brand_name, brand_type, brand_budget)
# VALUES
# (1, 'Doritos', 'Snacks', 7000000),
# (2, 'AWS', 'Technology', 15000000),
# (3, 'Pepsi', 'Beverages', 2000000),
# (4, 'He_Gets_Us', 'Religious', 1000000),
# (5, 'Dr_Pepper', 'Beverages', 5000000),
# (6, 'IBM', 'Technology', 100000),
# (7, 'Google', 'Technology', 8000000);]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)

# %%
#Block 3
# %%sql
SELECT * FROM Marketing_Brands;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [(1, 'Doritos', 'Snacks', 7000000),
#  (2, 'AWS', 'Technology', 15000000),
#  (3, 'Pepsi', 'Beverages', 2000000),
#  (4, 'He_Gets_Us', 'Religious', 1000000),
#  (5, 'Dr_Pepper', 'Beverages', 5000000),
#  (6, 'IBM', 'Technology', 100000),
#  (7, 'Google', 'Technology', 8000000)]

# %%
#Block 4
# %%sql
-- Instructions: Fix the code to display only the brand names and brand
SELECT brand_name, brand_type FROM Marketing_Brands;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [('Doritos', 'Snacks'),
#  ('AWS', 'Technology'),
#  ('Pepsi', 'Beverages'),
#  ('He_Gets_Us', 'Religious'),
#  ('Dr_Pepper', 'Beverages'),
#  ('IBM', 'Technology'),
#  ('Google', 'Technology')]

# %%
#Block 5
# %%sql
SELECT *
FROM Marketing_Brands
WHERE brand_type = 'Religious';
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [(4, 'He_Gets_Us', 'Religious', 1000000)]

# %%
#Block 6
# %%sql
SELECT brand_name
FROM Marketing_Brands
WHERE brand_budget > 5000000;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [('Doritos',), ('AWS',), ('Google',)]

# %%
#Block 7
# %%sql
SELECT *
FROM Marketing_Brands
WHERE brand_budget > 7000000;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [(2, 'AWS', 'Technology', 15000000), (7, 'Google', 'Technology', 8000000)]

# %%
#Block 8
# %%sql
SELECT *
FROM Marketing_Brands
WHERE brand_type IN ('Snacks', 'Beverages');
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [(1, 'Doritos', 'Snacks', 7000000),
#  (3, 'Pepsi', 'Beverages', 2000000),
#  (5, 'Dr_Pepper', 'Beverages', 5000000)]

# %%
#Block 9
# %%sql
SELECT brand_name, brand_budget
FROM Marketing_Brands
ORDER BY brand_budget DESC;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [('AWS', 15000000),
#  ('Google', 8000000),
#  ('Doritos', 7000000),
#  ('Dr_Pepper', 5000000),
#  ('Pepsi', 2000000),
#  ('He_Gets_Us', 1000000),
#  ('IBM', 100000)]

# %%
#Block 10
import pandas as pd

df = pd.read_sql_query("SELECT * FROM Marketing_Brands;", conn)
df
# Out:
#    brand_id  brand_name  brand_type  brand_budget
# 0         1     Doritos      Snacks       7000000
# 1         2         AWS  Technology      15000000
# 2         3       Pepsi   Beverages       2000000
# 3         4  He_Gets_Us   Religious       1000000
# 4         5   Dr_Pepper   Beverages       5000000
# 5         6         IBM  Technology        100000
# 6         7      Google  Technology       8000000

# %% [markdown]
# Block #1: I added the missing word TABLE after CREATE.

# %% [markdown]
# Block #2: I added INTO Marketing_Brands after INSERT and kept the column list.

# %% [markdown]
# Block #3: I added * so it selects all columns.

# %% [markdown]
# Block #4: I listed the specific columns: brand_name, brand_budget.

# %% [markdown]
# Block #5: I added a WHERE clause to filter brand_type = 'Religious'.

# %% [markdown]
# Block #6: I selected only brand_name and added a WHERE clause to filter by budget.

# %% [markdown]
# Block #7: I added %%sql so the cell runs as SQL (not Python).

# %% [markdown]
# Block #8: I added a filter for Snacks or Beverages using IN (...).

# %% [markdown]
# Block #9: I finished the SELECT and added ORDER BY brand_budget DESC.

# %% [markdown]
# Block #10: I used pd.read_sql_query() with the connection to show the table as a dataframe.
